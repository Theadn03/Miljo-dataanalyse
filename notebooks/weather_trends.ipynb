# %% [markdown]
# **Visualisering av værdata**
#
# Vår visualisering av værdata er basert på historisk værdata mellom 01.01.2023 til 01.05.2025 fra 3 ulike byer - Steinkjer, Molde & Ålesund.

# %%
import os
import sys
sys.path.append(os.path.abspath("../src"))

import pandas as pd
from datetime import datetime
from fetch_data import fetch_data_from_frost
from process_data import process_and_clean_data
from visualize_data import (
    plot_temperature_trend,
    plot_environmental_factors,
    plot_precipitation,
    plot_wind_speed
)

# Les inn datasettet
file_path = '../data/weekly_weather_data.csv'
df = pd.read_csv(file_path)
df['Time'] = pd.to_datetime(df['Time'])
print("Data loaded")
# Out:
# /Users/eier/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Data loaded

# %%
plot_temperature_trend(df)
plot_environmental_factors(df)
plot_precipitation(df)
plot_wind_speed(df)
# Out:
#                        elementId  value  unit  \
# 0      mean(air_temperature P1D)   -2.8  degC
# 1      mean(air_temperature P1D)    1.0  degC
# 4      mean(air_temperature P1D)  -10.3  degC
# 5      mean(air_temperature P1D)   -5.1  degC
# 8      mean(air_temperature P1D)   -5.8  degC
# ...                          ...    ...   ...
# 10541  mean(air_temperature P1D)    7.6  degC
# 10545  mean(air_temperature P1D)    7.9  degC
# 10546  mean(air_temperature P1D)    7.9  degC
# 10550  mean(air_temperature P1D)    6.3  degC
# 10551  mean(air_temperature P1D)    7.1  degC
#
#                                                    level timeOffset  \
# 0      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1      {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 4      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 5      {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 8      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 10541  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 10545  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10546  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 10550  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10551  {'levelType': 'height_above_ground', 'unit': '...       PT6H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 0                P1D             0                   C                 1
# 1                P1D             0                   C                 1
# 4                P1D             0                   C                 1
# 5                P1D             0                   C                 1
# 8                P1D             0                   C                 1
# ...              ...           ...                 ...               ...
# 10541            P1D             0                   C                 1
# 10545            P1D             0                   C                 1
# 10546            P1D             0                   C                 1
# 10550            P1D             0                   C                 1
# 10551            P1D             0                   C                 1
#
#        qualityCode                      Time   Location
# 0              0.0 2023-01-01 00:00:00+00:00  Steinkjer
# 1              2.0 2023-01-01 00:00:00+00:00  Steinkjer
# 4              0.0 2023-01-02 00:00:00+00:00  Steinkjer
# 5              2.0 2023-01-02 00:00:00+00:00  Steinkjer
# 8              0.0 2023-01-03 00:00:00+00:00  Steinkjer
# ...            ...                       ...        ...
# 10541          0.0 2025-04-28 00:00:00+00:00  Steinkjer
# 10545          0.0 2025-04-29 00:00:00+00:00  Steinkjer
# 10546          0.0 2025-04-29 00:00:00+00:00  Steinkjer
# 10550          0.0 2025-04-30 00:00:00+00:00  Steinkjer
# 10551          0.0 2025-04-30 00:00:00+00:00  Steinkjer
#
# [1702 rows x 12 columns]
#                        elementId  value  unit  \
# 1794   mean(air_temperature P1D)   -7.0  degC
# 1795   mean(air_temperature P1D)   -1.3  degC
# 1799   mean(air_temperature P1D)   -6.7  degC
# 1800   mean(air_temperature P1D)   -8.5  degC
# 1804   mean(air_temperature P1D)   -8.5  degC
# ...                          ...    ...   ...
# 11146  mean(air_temperature P1D)    8.1  degC
# 11150  mean(air_temperature P1D)    5.9  degC
# 11151  mean(air_temperature P1D)    6.6  degC
# 11155  mean(air_temperature P1D)    6.1  degC
# 11156  mean(air_temperature P1D)    5.5  degC
#
#                                                    level timeOffset  \
# 1794   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1795   {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 1799   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1800   {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 1804   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 11146  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 11150  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11151  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 11155  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11156  {'levelType': 'height_above_ground', 'unit': '...       PT6H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 1794             P1D             0                   C                 2
# 1795             P1D             0                   C                 2
# 1799             P1D             0                   C                 2
# 1800             P1D             0                   C                 2
# 1804             P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 11146            P1D             0                   C                 2
# 11150            P1D             0                   C                 2
# 11151            P1D             0                   C                 2
# 11155            P1D             0                   C                 2
# 11156            P1D             0                   C                 2
#
#        qualityCode                      Time Location
# 1794           0.0 2023-01-01 00:00:00+00:00    Molde
# 1795           2.0 2023-01-01 00:00:00+00:00    Molde
# 1799           0.0 2023-01-02 00:00:00+00:00    Molde
# 1800           2.0 2023-01-02 00:00:00+00:00    Molde
# 1804           0.0 2023-01-03 00:00:00+00:00    Molde
# ...            ...                       ...      ...
# 11146          0.0 2025-04-28 00:00:00+00:00    Molde
# 11150          0.0 2025-04-29 00:00:00+00:00    Molde
# 11151          0.0 2025-04-29 00:00:00+00:00    Molde
# 11155          0.0 2025-04-30 00:00:00+00:00    Molde
# 11156          0.0 2025-04-30 00:00:00+00:00    Molde
#
# [1702 rows x 12 columns]
#                        elementId  value  unit  \
# 3619   mean(air_temperature P1D)   -0.9  degC
# 3620   mean(air_temperature P1D)    2.0  degC
# 3624   mean(air_temperature P1D)   -0.4  degC
# 3625   mean(air_temperature P1D)   -1.6  degC
# 3629   mean(air_temperature P1D)   -0.8  degC
# ...                          ...    ...   ...
# 11751  mean(air_temperature P1D)   10.3  degC
# 11755  mean(air_temperature P1D)    8.2  degC
# 11756  mean(air_temperature P1D)    8.9  degC
# 11760  mean(air_temperature P1D)    8.8  degC
# 11761  mean(air_temperature P1D)    8.1  degC
#
#                                                    level timeOffset  \
# 3619   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3620   {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 3624   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3625   {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 3629   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 11751  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 11755  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11756  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 11760  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11761  {'levelType': 'height_above_ground', 'unit': '...       PT6H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 3619             P1D             0                   C                 2
# 3620             P1D             0                   C                 2
# 3624             P1D             0                   C                 2
# 3625             P1D             0                   C                 2
# 3629             P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 11751            P1D             0                   C                 2
# 11755            P1D             0                   C                 2
# 11756            P1D             0                   C                 2
# 11760            P1D             0                   C                 2
# 11761            P1D             0                   C                 2
#
#        qualityCode                      Time Location
# 3619           0.0 2023-01-01 00:00:00+00:00  Ålesund
# 3620           2.0 2023-01-01 00:00:00+00:00  Ålesund
# 3624           0.0 2023-01-02 00:00:00+00:00  Ålesund
# 3625           2.0 2023-01-02 00:00:00+00:00  Ålesund
# 3629           0.0 2023-01-03 00:00:00+00:00  Ålesund
# ...            ...                       ...      ...
# 11751          0.0 2025-04-28 00:00:00+00:00  Ålesund
# 11755          0.0 2025-04-29 00:00:00+00:00  Ålesund
# 11756          0.0 2025-04-29 00:00:00+00:00  Ålesund
# 11760          0.0 2025-04-30 00:00:00+00:00  Ålesund
# 11761          0.0 2025-04-30 00:00:00+00:00  Ålesund
#
# [1702 rows x 12 columns]
#                          elementId  value     unit  \
# 3      mean(relative_humidity P1D)   85.0  percent
# 7      mean(relative_humidity P1D)   80.0  percent
# 11     mean(relative_humidity P1D)   88.0  percent
# 15     mean(relative_humidity P1D)   70.0  percent
# 19     mean(relative_humidity P1D)   64.0  percent
# ...                            ...    ...      ...
# 10534  mean(relative_humidity P1D)   62.0  percent
# 10539  mean(relative_humidity P1D)   74.0  percent
# 10544  mean(relative_humidity P1D)   91.0  percent
# 10549  mean(relative_humidity P1D)   81.0  percent
# 10554  mean(relative_humidity P1D)   82.0  percent
#
#                                                    level timeOffset  \
# 3      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 7      {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11     {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 15     {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 19     {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 10534  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10539  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10544  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10549  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10554  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 3                P1D             0                   C                 1
# 7                P1D             0                   C                 1
# 11               P1D             0                   C                 1
# 15               P1D             0                   C                 1
# 19               P1D             0                   C                 1
# ...              ...           ...                 ...               ...
# 10534            P1D             0                   C                 1
# 10539            P1D             0                   C                 1
# 10544            P1D             0                   C                 1
# 10549            P1D             0                   C                 1
# 10554            P1D             0                   C                 1
#
#        qualityCode                      Time   Location
# 3              2.0 2023-01-01 00:00:00+00:00  Steinkjer
# 7              2.0 2023-01-02 00:00:00+00:00  Steinkjer
# 11             2.0 2023-01-03 00:00:00+00:00  Steinkjer
# 15             2.0 2023-01-04 00:00:00+00:00  Steinkjer
# 19             2.0 2023-01-05 00:00:00+00:00  Steinkjer
# ...            ...                       ...        ...
# 10534          0.0 2025-04-26 00:00:00+00:00  Steinkjer
# 10539          0.0 2025-04-27 00:00:00+00:00  Steinkjer
# 10544          0.0 2025-04-28 00:00:00+00:00  Steinkjer
# 10549          0.0 2025-04-29 00:00:00+00:00  Steinkjer
# 10554          0.0 2025-04-30 00:00:00+00:00  Steinkjer
#
# [850 rows x 12 columns]
#                          elementId  value     unit  \
# 1798   mean(relative_humidity P1D)   88.0  percent
# 1803   mean(relative_humidity P1D)   86.0  percent
# 1808   mean(relative_humidity P1D)   86.0  percent
# 1813   mean(relative_humidity P1D)   51.0  percent
# 1818   mean(relative_humidity P1D)   59.0  percent
# ...                            ...    ...      ...
# 11139  mean(relative_humidity P1D)   70.0  percent
# 11144  mean(relative_humidity P1D)   75.0  percent
# 11149  mean(relative_humidity P1D)   99.0  percent
# 11154  mean(relative_humidity P1D)   99.0  percent
# 11159  mean(relative_humidity P1D)   92.0  percent
#
#                                                    level timeOffset  \
# 1798   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1803   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1808   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1813   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1818   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 11139  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11144  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11149  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11154  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11159  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 1798             P1D             0                   C                 2
# 1803             P1D             0                   C                 2
# 1808             P1D             0                   C                 2
# 1813             P1D             0                   C                 2
# 1818             P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 11139            P1D             0                   C                 2
# 11144            P1D             0                   C                 2
# 11149            P1D             0                   C                 2
# 11154            P1D             0                   C                 2
# 11159            P1D             0                   C                 2
#
#        qualityCode                      Time Location
# 1798           2.0 2023-01-01 00:00:00+00:00    Molde
# 1803           2.0 2023-01-02 00:00:00+00:00    Molde
# 1808           2.0 2023-01-03 00:00:00+00:00    Molde
# 1813           2.0 2023-01-04 00:00:00+00:00    Molde
# 1818           2.0 2023-01-05 00:00:00+00:00    Molde
# ...            ...                       ...      ...
# 11139          0.0 2025-04-26 00:00:00+00:00    Molde
# 11144          0.0 2025-04-27 00:00:00+00:00    Molde
# 11149          0.0 2025-04-28 00:00:00+00:00    Molde
# 11154          0.0 2025-04-29 00:00:00+00:00    Molde
# 11159          0.0 2025-04-30 00:00:00+00:00    Molde
#
# [851 rows x 12 columns]
#                          elementId  value     unit  \
# 3623   mean(relative_humidity P1D)   97.0  percent
# 3628   mean(relative_humidity P1D)   96.0  percent
# 3633   mean(relative_humidity P1D)   97.0  percent
# 3638   mean(relative_humidity P1D)   74.0  percent
# 3643   mean(relative_humidity P1D)   76.0  percent
# ...                            ...    ...      ...
# 11744  mean(relative_humidity P1D)   64.0  percent
# 11749  mean(relative_humidity P1D)   68.0  percent
# 11754  mean(relative_humidity P1D)   85.0  percent
# 11759  mean(relative_humidity P1D)   89.0  percent
# 11764  mean(relative_humidity P1D)   78.0  percent
#
#                                                    level timeOffset  \
# 3623   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3628   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3633   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3638   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 3643   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ...                                                  ...        ...
# 11744  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11749  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11754  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11759  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11764  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 3623             P1D             0                   C                 2
# 3628             P1D             0                   C                 2
# 3633             P1D             0                   C                 2
# 3638             P1D             0                   C                 2
# 3643             P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 11744            P1D             0                   C                 2
# 11749            P1D             0                   C                 2
# 11754            P1D             0                   C                 2
# 11759            P1D             0                   C                 2
# 11764            P1D             0                   C                 2
#
#        qualityCode                      Time Location
# 3623           2.0 2023-01-01 00:00:00+00:00  Ålesund
# 3628           2.0 2023-01-02 00:00:00+00:00  Ålesund
# 3633           2.0 2023-01-03 00:00:00+00:00  Ålesund
# 3638           2.0 2023-01-04 00:00:00+00:00  Ålesund
# 3643           2.0 2023-01-05 00:00:00+00:00  Ålesund
# ...            ...                       ...      ...
# 11744          0.0 2025-04-26 00:00:00+00:00  Ålesund
# 11749          0.0 2025-04-27 00:00:00+00:00  Ålesund
# 11754          0.0 2025-04-28 00:00:00+00:00  Ålesund
# 11759          0.0 2025-04-29 00:00:00+00:00  Ålesund
# 11764          0.0 2025-04-30 00:00:00+00:00  Ålesund
#
# [850 rows x 12 columns]
#                            elementId  value unit level timeOffset  \
# 360    sum(precipitation_amount P1D)    0.0   mm   NaN      PT18H
# 361    sum(precipitation_amount P1D)    0.0   mm   NaN       PT6H
# 366    sum(precipitation_amount P1D)    0.0   mm   NaN      PT18H
# 367    sum(precipitation_amount P1D)    0.0   mm   NaN       PT6H
# 371    sum(precipitation_amount P1D)    0.2   mm   NaN      PT18H
# ...                              ...    ...  ...   ...        ...
# 10543  sum(precipitation_amount P1D)    2.8   mm   NaN       PT6H
# 10547  sum(precipitation_amount P1D)    2.2   mm   NaN      PT18H
# 10548  sum(precipitation_amount P1D)   10.0   mm   NaN       PT6H
# 10552  sum(precipitation_amount P1D)    9.8   mm   NaN      PT18H
# 10553  sum(precipitation_amount P1D)   10.4   mm   NaN       PT6H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 360              P1D             0                   C                 2
# 361              P1D             0                   C                 2
# 366              P1D             0                   C                 2
# 367              P1D             0                   C                 2
# 371              P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 10543            P1D             0                   C                 2
# 10547            P1D             0                   C                 2
# 10548            P1D             0                   C                 2
# 10552            P1D             0                   C                 2
# 10553            P1D             0                   C                 2
#
#        qualityCode                      Time   Location
# 360            2.0 2023-04-01 00:00:00+00:00  Steinkjer
# 361            1.0 2023-04-01 00:00:00+00:00  Steinkjer
# 366            2.0 2023-04-02 00:00:00+00:00  Steinkjer
# 367            1.0 2023-04-02 00:00:00+00:00  Steinkjer
# 371            2.0 2023-04-03 00:00:00+00:00  Steinkjer
# ...            ...                       ...        ...
# 10543          0.0 2025-04-28 00:00:00+00:00  Steinkjer
# 10547          0.0 2025-04-29 00:00:00+00:00  Steinkjer
# 10548          0.0 2025-04-29 00:00:00+00:00  Steinkjer
# 10552          0.0 2025-04-30 00:00:00+00:00  Steinkjer
# 10553          0.0 2025-04-30 00:00:00+00:00  Steinkjer
#
# [1107 rows x 12 columns]
#                            elementId  value unit level timeOffset  \
# 1796   sum(precipitation_amount P1D)    7.1   mm   NaN      PT18H
# 1797   sum(precipitation_amount P1D)   22.0   mm   NaN       PT6H
# 1801   sum(precipitation_amount P1D)    0.0   mm   NaN      PT18H
# 1802   sum(precipitation_amount P1D)    0.0   mm   NaN       PT6H
# 1806   sum(precipitation_amount P1D)    0.0   mm   NaN      PT18H
# ...                              ...    ...  ...   ...        ...
# 11148  sum(precipitation_amount P1D)    6.9   mm   NaN       PT6H
# 11152  sum(precipitation_amount P1D)   21.8   mm   NaN      PT18H
# 11153  sum(precipitation_amount P1D)   35.8   mm   NaN       PT6H
# 11157  sum(precipitation_amount P1D)    6.0   mm   NaN      PT18H
# 11158  sum(precipitation_amount P1D)   10.9   mm   NaN       PT6H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 1796             P1D             0                   C                 2
# 1797             P1D             0                   C                 2
# 1801             P1D             0                   C                 2
# 1802             P1D             0                   C                 2
# 1806             P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 11148            P1D             0                   C                 2
# 11152            P1D             0                   C                 2
# 11153            P1D             0                   C                 2
# 11157            P1D             0                   C                 2
# 11158            P1D             0                   C                 2
#
#        qualityCode                      Time Location
# 1796           2.0 2023-01-01 00:00:00+00:00    Molde
# 1797           1.0 2023-01-01 00:00:00+00:00    Molde
# 1801           2.0 2023-01-02 00:00:00+00:00    Molde
# 1802           0.0 2023-01-02 00:00:00+00:00    Molde
# 1806           2.0 2023-01-03 00:00:00+00:00    Molde
# ...            ...                       ...      ...
# 11148          0.0 2025-04-28 00:00:00+00:00    Molde
# 11152          0.0 2025-04-29 00:00:00+00:00    Molde
# 11153          0.0 2025-04-29 00:00:00+00:00    Molde
# 11157          0.0 2025-04-30 00:00:00+00:00    Molde
# 11158          0.0 2025-04-30 00:00:00+00:00    Molde
#
# [1128 rows x 12 columns]
#                            elementId  value unit level timeOffset  \
# 3621   sum(precipitation_amount P1D)    1.3   mm   NaN      PT18H
# 3622   sum(precipitation_amount P1D)   11.0   mm   NaN       PT6H
# 3626   sum(precipitation_amount P1D)    0.0   mm   NaN      PT18H
# 3627   sum(precipitation_amount P1D)    0.0   mm   NaN       PT6H
# 3631   sum(precipitation_amount P1D)    0.0   mm   NaN      PT18H
# ...                              ...    ...  ...   ...        ...
# 11753  sum(precipitation_amount P1D)    6.3   mm   NaN       PT6H
# 11757  sum(precipitation_amount P1D)    6.5   mm   NaN      PT18H
# 11758  sum(precipitation_amount P1D)    6.8   mm   NaN       PT6H
# 11762  sum(precipitation_amount P1D)    2.2   mm   NaN      PT18H
# 11763  sum(precipitation_amount P1D)    6.5   mm   NaN       PT6H
#
#       timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 3621             P1D             0                   C                 2
# 3622             P1D             0                   C                 2
# 3626             P1D             0                   C                 2
# 3627             P1D             0                   C                 2
# 3631             P1D             0                   C                 2
# ...              ...           ...                 ...               ...
# 11753            P1D             0                   C                 2
# 11757            P1D             0                   C                 2
# 11758            P1D             0                   C                 2
# 11762            P1D             0                   C                 2
# 11763            P1D             0                   C                 2
#
#        qualityCode                      Time Location
# 3621           2.0 2023-01-01 00:00:00+00:00  Ålesund
# 3622           0.0 2023-01-01 00:00:00+00:00  Ålesund
# 3626           2.0 2023-01-02 00:00:00+00:00  Ålesund
# 3627           0.0 2023-01-02 00:00:00+00:00  Ålesund
# 3631           2.0 2023-01-03 00:00:00+00:00  Ålesund
# ...            ...                       ...      ...
# 11753          0.0 2025-04-28 00:00:00+00:00  Ålesund
# 11757          0.0 2025-04-29 00:00:00+00:00  Ålesund
# 11758          0.0 2025-04-29 00:00:00+00:00  Ålesund
# 11762          0.0 2025-04-30 00:00:00+00:00  Ålesund
# 11763          0.0 2025-04-30 00:00:00+00:00  Ålesund
#
# [1702 rows x 12 columns]
#                 elementId  value unit  \
# 2    mean(wind_speed P1D)    2.3  m/s
# 6    mean(wind_speed P1D)    3.7  m/s
# 10   mean(wind_speed P1D)    1.7  m/s
# 14   mean(wind_speed P1D)    2.8  m/s
# 18   mean(wind_speed P1D)    8.4  m/s
# ..                    ...    ...  ...
# 899  mean(wind_speed P1D)    0.5  m/s
# 905  mean(wind_speed P1D)    1.0  m/s
# 916  mean(wind_speed P1D)    0.8  m/s
# 947  mean(wind_speed P1D)    1.5  m/s
# 953  mean(wind_speed P1D)    2.2  m/s
#
#                                                  level timeOffset  \
# 2    {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 6    {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 14   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 18   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# ..                                                 ...        ...
# 899  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 905  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 916  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 947  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 953  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#     timeResolution  timeSeriesId performanceCategory  exposureCategory  \
# 2              P1D             0                   C                 2
# 6              P1D             0                   C                 2
# 10             P1D             0                   C                 2
# 14             P1D             0                   C                 2
# 18             P1D             0                   C                 2
# ..             ...           ...                 ...               ...
# 899            P1D             0                   C                 2
# 905            P1D             0                   C                 2
# 916            P1D             0                   C                 2
# 947            P1D             0                   C                 2
# 953            P1D             0                   C                 2
#
#      qualityCode                      Time   Location
# 2            2.0 2023-01-01 00:00:00+00:00  Steinkjer
# 6            2.0 2023-01-02 00:00:00+00:00  Steinkjer
# 10           2.0 2023-01-03 00:00:00+00:00  Steinkjer
# 14           2.0 2023-01-04 00:00:00+00:00  Steinkjer
# 18           2.0 2023-01-05 00:00:00+00:00  Steinkjer
# ..           ...                       ...        ...
# 899          1.0 2023-07-02 00:00:00+00:00  Steinkjer
# 905          1.0 2023-07-03 00:00:00+00:00  Steinkjer
# 916          1.5 2023-07-05 00:00:00+00:00  Steinkjer
# 947          1.5 2023-07-11 00:00:00+00:00  Steinkjer
# 953          1.0 2023-07-12 00:00:00+00:00  Steinkjer
#
# [171 rows x 12 columns]

# %% [markdown]
# **Temperaturutvikling**
# Den første grafen viser utviklingen i temperatur kl 12:00 hver mandag i hele måleperioden. Vi ser tydelige sesongvariasjoner: temperaturene stiger om våren og sommeren og synker om høsten og vinteren. Steinkjer har generelt de laveste temperaturene, spesielt vinterstid, noe som er forventet siden det ligger lengre nord og mer innlands. Ålesund viser de høyeste temperaturene, særlig i vintersesongen, noe som trolig skyldes den milde kystklimaeffekten. Molde ligger midt imellom. Det er tydelig at temperaturvariasjonene følger et naturlig mønster og gir god støtte for videre analyse.
#
# **Luftfuktighet**
# Grafen over relativ luftfuktighet viser at alle tre byer i stor grad ligger høyt, ofte mellom 70–100 %. Steinkjer har en tendens til litt lavere verdier i perioder, noe som kan forklares av kaldere og tørrere innlandsvær. Ålesund, med sin beliggenhet ved kysten, har generelt høy luftfuktighet med mindre variasjon. Dette er i tråd med forventningene for et fuktig og mildt kystklima. Molde viser litt større variasjon i luftfuktighet sammenlignet med Ålesund, men følger et lignende mønster.
#
# **Nedbør**
# I nedbørsgrafen ser vi at Ålesund skiller seg klart ut med hyppigere og kraftigere nedbørstopper. Dette er helt i tråd med kjente værforhold på Vestlandet, hvor fjell og hav skaper mye nedbør. Molde har også en del nedbør, men ikke like intensivt eller hyppig som Ålesund. Steinkjer har klart færrest episoder med høy nedbør, og viser et tørrere mønster generelt. Her blir det tydelig hvordan geografisk plassering påvirker nedbørsmengder kraftig.
#
# **Vindhastighet**
# Den siste grafen viser utviklingen i vindhastighet, men kun for Steinkjer. Ved innhenting av data så er det kun registert målinger ved målestasjonen til Steinkjer i perioden januar til juli 2023. Dette er en kort periode så man har ikke mulighetentil å sammenligne resultatet med andre år, noe som begrenser muligheten for å analysere funnet. Vi ser at vindstyrken i Steinkjer oftest ligger mellom 1 og 3 m/s, med enkelte topper på 6–8 m/s i perioden. Det er tydelig at vind er mest intens i vintermånedene og roligere gjennom sommeren.
